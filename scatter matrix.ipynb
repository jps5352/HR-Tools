# %%
import pandas as pd
df= pd.read_excel('C:\\mean median mode.xlsx')

# %%
df.plot.scatter(x='age',y='salary_2018')

# %%
df1=df[['age','salary_2018','totalW_working_years','percent_hike']]

# %%
df1.columns
# Out:
# Index(['age', 'salary_2018', 'totalW_working_years', 'percent_hike'], dtype='object')

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df1,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000247D73CB548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7C6D688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7CA6748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7CDE848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7D18948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7D4FA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7D88B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7DC0C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7DCA808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7E04A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7E69F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7EA6048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7EDE188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7F16288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7F50388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000247D7F8A4C8>]],
#       dtype=object)
