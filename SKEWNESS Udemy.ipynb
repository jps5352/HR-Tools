# %%
import pandas as pd

df = pd.read_excel('Skewness.xlsx')

# %%
df.head()
# Out:
#    manager_sat  employee_sat  salary_2017  percent_salary_hike  age
# 0           81            80       119968             0.952381   41
# 1           88            84        99330             1.818182   49
# 2           83            93       102511             1.739130   37
# 3           86            83        56674             1.666667   33
# 4           79            80       122021             2.400000   27

# %%
df['manager_sat'].plot.hist()
df['manager_sat'].skew()
# Out:
# 1.2416158547092389

# %%
from sklearn import preprocessing

# %%
std_df = preprocessing.scale(df['salary_2017'])

# %%
std_df
# Out:
# array([ 9.34386821e-02, -2.46132919e-01, -1.93793677e-01, -9.47982236e-01,
#         1.27218142e-01,  1.56538648e-01,  6.62802752e-01,  2.50357684e-01,
#        -6.12754414e-01,  5.92331526e-01, -5.77346037e-01, -6.19368804e-01,
#        -6.39573956e-01, -1.00803827e+00, -3.36908019e-01, -4.68751572e-01,
#        -9.48623930e-01, -9.79145557e-01, -8.08981321e-01, -3.89806687e-01,
#         2.37112450e-01, -4.93942197e-01, -2.99130308e-01, -4.03594893e-01,
#        -8.45410643e-02,  7.80084774e-01,  1.12010063e+00, -6.15238923e-01,
#        -2.51562642e-01, -7.47181198e-01, -5.36178862e-01, -9.17148805e-02,
#         1.28517985e-01, -1.08974819e-01, -4.27600851e-01, -4.89598418e-01,
#        -4.89713594e-01, -2.11267514e-01, -5.23048804e-01,  1.99235201e-02,
#         1.50352054e-01, -6.34242955e-01, -6.88655363e-01, -1.02801307e+00,
#        -3.26706721e-01,  1.32837165e+00, -1.94007576e-01, -1.19735543e-01,
# ...
